# %%
import sys
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
pd.set_option("display.max_columns", None)
import warnings
warnings.filterwarnings('ignore')

# %%
import joblib

# %%
 import pytz
'{:%Y-%m-%d %H:%M:%S}'.format(datetime.now(tz = pytz.timezone('Asia/Jakarta')))
# Out:
# '2024-09-04 19:51:32'

# %%
pipeline = joblib.load('D:\guthib file\compfest_aic_16 - randomized\models\pipeline.pkl')
model = joblib.load('D:\guthib file\compfest_aic_16 - randomized\models\model_burnout.pkl')

# %%
input_data = {
'Designation': [1.],
'Resource Allocation': [2.],
'Mental Fatigue Score': [5.],
'Gender': ['Male'],
'Company Type': ['Service'],
'WFH Setup Available': ["Yes"]
}

input_df = pd.DataFrame(input_data)

# %%
trnf = pipeline.transform(input_df)

# %%
np.round(model.predict(trnf)[0],2)
# Out:
# 0.34

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1pkqLHjqbjOZq1avSZscC4K6vlhpbD6pBAaui2N7-HT4/pub?gid=0&single=true&output=csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
fig = px.histogram(df, x='Gender', color='Company Type', barmode='group')
fig.show()
# Out:
# <div>                            <div id="221871f7-d7c7-437a-b7a0-10b8c5122b57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("221871f7-d7c7-437a-b7a0-10b8c5122b57")) {                    Plotly.newPlot(                        "221871f7-d7c7-437a-b7a0-10b8c5122b57",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Company Type=Service\u003cbr\u003eGender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Service","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Service","offsetgroup":"Service","orientation":"v","showlegend":true,"x":["Female","Male","Male","Female","Female","Female","Male","Female","Male","Male","Male","Male","Male","Female","Female","Female","Female","Mal
# ...

# %%
sns.countplot(x = df['Gender'], hue = df['Company Type'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
fig = px.pie(df, names = 'Gender', title='Population of European continent')
fig.show()
# Out:
# <div>                            <div id="c4b61177-6b8b-43b4-a234-83ba0e19f44a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4b61177-6b8b-43b4-a234-83ba0e19f44a")) {                    Plotly.newPlot(                        "c4b61177-6b8b-43b4-a234-83ba0e19f44a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Gender=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Female","Male","Male","Female","Male","Female","Female","Male","Male","Male","Female","Male","Male","Female","Male","Male","Male","Male","Female","Female","Female","Female","Female","Male","Male","Male","Female","Female","Female","Female","Female","Male","Female","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male
# ...

# %%
fig = px.scatter(df, x="Mental Fatigue Score", y="Burn Rate", color="Company Type")
fig.show()
# Out:
# <div>                            <div id="53476b51-3731-4da9-b1d6-58f9f4e80aed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53476b51-3731-4da9-b1d6-58f9f4e80aed")) {                    Plotly.newPlot(                        "53476b51-3731-4da9-b1d6-58f9f4e80aed",                        [{"hovertemplate":"Company Type=Service\u003cbr\u003eMental Fatigue Score=%{x}\u003cbr\u003eBurn Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Service","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Service","showlegend":true,"x":[3.8,5.0,2.6,6.9,7.9,4.4,1.8,4.7,5.9,6.7,6.3,6.7,6.6,7.4,6.7,3.9,3.0,4.7,4.4,5.8,6.6,7.3,5.0,6.0,7.5,10.0,7.4,6.4,5.6,8.0,3.6,6.8,4.9,9.2,6.5,6.8,6.2,5.8,4.9,4.1,7.4,4.4,6.9,4.3,2.9,5.0,6.9,4.7
# ...

# %%
df#.isnull().sum()
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe32003400380032003900      2008-11-03    Male      Service
# 3      fffe31003900340031003600      2008-07-24  Female      Service
# 4          fffe3300350037003500      2008-11-26    Male      Product
# ...                         ...             ...     ...          ...
# 18585      fffe3300390030003600      2008-12-15  Female      Product
# 18586  fffe32003500370033003200      2008-05-27    Male      Product
# 18587  fffe33003000350031003800      2008-01-19  Female      Product
# 18588  fffe33003300320036003900      2008-01-10  Female      Service
# 18589      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# ...

# %%
df.describe()
# Out:
#         Designation  Resource Allocation  Mental Fatigue Score     Burn Rate
# count  18590.000000         18590.000000          18590.000000  18590.000000
# mean       2.179398             4.486552              5.732173      0.452444
# std        1.133148             2.044848              1.920547      0.197848
# min        0.000000             1.000000              0.000000      0.000000
# 25%        1.000000             3.000000              4.600000      0.320000
# 50%        2.000000             4.000000              5.900000      0.450000
# 75%        3.000000             6.000000              7.100000      0.590000
# max        5.000000            10.000000             10.000000      1.000000

# %%
df
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe32003400380032003900      2008-11-03    Male      Service
# 3      fffe31003900340031003600      2008-07-24  Female      Service
# 4          fffe3300350037003500      2008-11-26    Male      Product
# ...                         ...             ...     ...          ...
# 18585      fffe3300390030003600      2008-12-15  Female      Product
# 18586  fffe32003500370033003200      2008-05-27    Male      Product
# 18587  fffe33003000350031003800      2008-01-19  Female      Product
# 18588  fffe33003300320036003900      2008-01-10  Female      Service
# 18589      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# ...

# %%
sns.barplot(data = df, x = 'WFH Setup Available', y = 'Mental Fatigue Score')
plt.yticks([i for i in range(11)])
# Out:
# ([<matplotlib.axis.YTick at 0x722c85b0ff40>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 1, '1'),
#   Text(0, 2, '2'),
#   Text(0, 3, '3'),
#   Text(0, 4, '4'),
#   Text(0, 5, '5'),
#   Text(0, 6, '6'),
#   Text(0, 7, '7'),
#   Text(0, 8, '8'),
#   Text(0, 9, '9'),
#   Text(0, 10, '10')])

# %%
df['Designation'].astype(float).unique()
# Out:
# array([2., 1., 3., 0., 4., 5.])

# %%
sns.scatterplot(x = df['Resource Allocation'], y = df['Mental Fatigue Score'])
# Out:
# <Axes: xlabel='Resource Allocation', ylabel='Mental Fatigue Score'>

# %%
df[['Designation', 'Resource Allocation', 'Mental Fatigue Score', 'Gender', 'Company Type', 'WFH Setup Available']]
# Out:
#        Designation  Resource Allocation  Mental Fatigue Score  Gender  \
# 0              2.0                  5.0                   7.7  Female
# 1              1.0                  2.0                   5.2  Female
# 2              1.0                  3.0                   5.9    Male
# 3              3.0                  6.0                   4.6  Female
# 4              2.0                  5.0                   6.4  Female
# ...            ...                  ...                   ...     ...
# 12245          1.0                  2.0                   6.1  Female
# 12246          2.0                  4.0                   5.9  Female
# 12247          4.0                  7.0                   9.6    Male
# 12248          3.0                  6.0                   6.7    Male
# 12249          2.0                  2.0                   2.0  Female
#
#       Company Type WFH Setup Available
# 0          Service                  No
# 1          Product                 Yes
# ...

# %%
sns.

# %% [markdown]
# ## analyze question
# ## 1 . berapa banyak yang melakukan survey dalam bentuk card
# ## 2 . distribusi kelamin dari orang yang melakukan survey bentuk bar chart
# ## 3 . detail dari data tersebut bagian bawah bentuk table
# ## 4 .

# %%
import streamlit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import streamlit
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
pip install streamlit
# Out:
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.9.0
#     Uninstalling typing-extensions-4.9.0:
#       Successfully uninstalled typing-extensions-4.9.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
streamlit.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 streamlit.__version__
#
# NameError: name 'streamlit' is not defined
